# %%
import datasets as ds

dataset = ds.OffensEvalData2020A(path = 'datasets/OffensEval20', n_max=-1)
s_train, s_test = dataset.getData()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2444/446538306.py in <cell line: 0>()
#       1 import datasets as ds
#       2
# ----> 3 dataset = ds.OffensEvalData2020A(path = 'datasets/OffensEval20', n_max=-1)
#       4 s_train, s_test = dataset.getData()
#
# AttributeError: module 'datasets' has no attribute 'OffensEvalData2020A'
